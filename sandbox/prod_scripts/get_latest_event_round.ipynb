# %%
import fastf1 as ff1

events = ff1.events.get_event_schedule(year = 2022)
# Out:
#    RoundNumber        Country     Location  \
# 0            0          Spain        Spain
# 1            0        Bahrain      Bahrain
# 2            1        Bahrain       Sakhir
# 3            2   Saudi Arabia       Jeddah
# 4            3      Australia    Melbourne
# 5            4          Italy        Imola
# 6            5  United States        Miami
# 7            6          Spain    Barcelona
# 8            7         Monaco  Monte Carlo
# 9            8     Azerbaijan         Baku
#
#                                    OfficialEventName           EventDate  \
# 0            FORMULA 1 PRE-SEASON TRACK SESSION 2022 2022-02-25 18:00:00
# 1           FORMULA 1 ARAMCO PRE-SEASON TESTING 2022 2022-03-12 19:00:00
# 2         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022 2022-03-20 20:00:00
# 3        FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2022 2022-03-27 22:00:00
# 4      FORMULA 1 HEINEKEN AUSTRALIAN GRAND PRIX 2022 2022-04-10 17:00:00
# ...

# %%
# Get most recent race
import datetime

now = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')

# %%
import pandas as pd
import numpy as np

values = events["Session5Date"] < now
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: Session5Date, dtype: bool

# %%
ind = np.where(values)[0].max()

# %%
round_number = int(events.iloc[[ind]]['RoundNumber'])
